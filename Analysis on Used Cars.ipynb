# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# - Write down some interesting introduction related to the topic.
#
# - Surf out over the internet and do some research about what is happening in real life.
#
# - Try out and make some concrete points about your point of view.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - This section is emphasised on providing some generic introduction to the problem that most companies confronts.
#
# - **Example Problem Statement:**
#
#   - In the past few years, prices of new cars have skyrocketed, due to which most people are incapable of buying a new one.
#
#   - Customers buying a new car always looks for assurity of their money to be worthy.
#
#   - But due to the increased price of new cars, used car sales are on a global increase (Pal, Arora and Palakurthy, 2018).
#
#   - There is a need for a used car price prediction system to effectively determine the worthiness of the car using a variety of features.
#
#   - Even though there are websites that offers this service, their prediction method may not be the best.
#
#   - Besides, different models and systems may contribute on predicting power for a used car’s actual market value.
#
#   - It is important to know their actual market value while both buying and selling.
#
# <p align="center"><img src="https://visme.co/blog/wp-content/uploads/2020/06/animated-interactive-infographics-header-wide.gif"></p>
#
# - Derive a scenario related to the problem statement and heads on to the journey of exploration.
#
# - **Example Scenario:**
#   - Cars Absolute, an American company buys and sells second hand cars.
#
#   - The company has earned its name because of sincerity in work and quality of services.
#
#   - But for past few months their sales is down for some reason and they are unable to figure it out.
#
#   - To tackle this problem they hired a genius team of data scientists. Consider you are one of them...

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                                         
# !pip install -q pandas-profiling

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
#-------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This section is emphasised on the accquiring the data and obtain some descriptive information out of it.
#
# - You could either scrap the data and then continue, or use a direct source of link (generally preferred in most cases).
#
# - You will be working with a direct source of link to head start your work without worrying about anything.
#
# - Before going further you must have a good idea about the features of the data set:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01| car           | Car brand name|
# |02| model         | Available car different Variants|
# |03| year          | purchasing Year|
# |04| body          | Body type-Hatchback, Sedan, Crossover etc|
# |05| mileage       | car Mileage|
# |06| engV          | Engine version|
# |07| engType       | Car Fuel type - Petrol, Diesel, gas etc|
# |08| drive         | Wheel Drive Front, back|
# |09| registration  | Check if the vechile is registered|
# |10| price         | Price of Car in $|

# %%
Car_data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv', encoding='cp1252')
print('Data Shape:', Car_data.shape)
Car_data.head()
# Out:
# Data Shape: (9576, 10)
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
# Insert your code here...
Car_data.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %% [markdown]
# ### **Data Information**

# %%
# Insert your code here...
Car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
# Insert your code here...
#prof_data = ProfileReport(data)
#prof_data

profile = Car_data.profile_report(title="Car Data Profiling before Data processing", progress_bar=False, minimal=True)
profile.to_file(output_file="Car_data_profiling_before_processing.html")

# %%
profile
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-06-09 19:44:44.956105&quot;&gt;&lt;title&gt;Car Data Profiling before Data processing&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
# Insert your code here... 
# Is there any null value in data set?
Car_data.isnull().any()
# Out:
# car             False
# price           False
# body            False
# mileage         False
# engV             True
# engType         False
# registration    False
# year            False
# model           False
# drive            True
# dtype: bool

# %%
# Engine Version plot
Car_data.engV.hist()
# Out:
# <AxesSubplot:>

# %%
# Type of drive in Car
Car_data.drive.hist()
# Out:
# <AxesSubplot:>

# %%
# Type of car
Car_data.car.hist()
# Out:
# <AxesSubplot:>

# %%
# Mileage of the Car
Car_data.mileage.hist()
# Out:
# <AxesSubplot:>

# %%
# Is there any null value in engv column
Car_data.engV.isnull().any()
# Out:
# True

# %%
# Is there any null value in price column
Car_data.price.isnull().any()
# Out:
# False

# %%
# Replace 'Zero' values in the price and mileage column with NaN
Car_data = Car_data.replace({
        'price': 0,
        'mileage': 0,
    }, np.nan)

# %%
# Fill NaN value with mode value
Car_data['engV']=Car_data['engV'].fillna(Car_data['engV'].mode()[0])

# %%
# Check the NaN value in engV column
Car_data.engV.isnull().any()
# Out:
# False

# %%
# Fill NaN value with mode value
Car_data['drive']=Car_data['drive'].fillna(Car_data['drive'].mode()[0])

# %%
# Check the NaN value in drive column
Car_data.drive.isnull().any()
# Out:
# False

# %%
# Fill NaN value with mode value
Car_data['price']=Car_data['price'].fillna(Car_data['price'].mode()[0])

# %%
# Fill NaN value with mode value
Car_data['mileage']=Car_data['mileage'].fillna(Car_data['mileage'].mode()[0])

# %%
# Check the null value in Data set
Car_data.isnull().any()
# Out:
# car             False
# price           False
# body            False
# mileage         False
# engV            False
# engType         False
# registration    False
# year            False
# model           False
# drive           False
# dtype: bool

# %%
# Drop the duplicate values
Car_data.drop_duplicates(keep = False, inplace = True)

# %%
# Check the duplicate data
duplicated = Car_data[Car_data.duplicated()]

# %%
# Print the info of the data 
Car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9362 entries, 2 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9362 non-null   object
#  1   price         9362 non-null   float64
#  2   body          9362 non-null   object
#  3   mileage       9362 non-null   float64
#  4   engV          9362 non-null   float64
#  5   engType       9362 non-null   object
#  6   registration  9362 non-null   object
#  7   year          9362 non-null   int64
#  8   model         9362 non-null   object
#  9   drive         9362 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 804.5+ KB

# %%
# Brief statistics of data set
Car_data.describe()
# Out:
#                price      mileage         engV         year
# count    9362.000000  9362.000000  9362.000000  9362.000000
# mean    15180.078916   140.975860     2.607885  2006.451079
# std     21950.323652    98.231663     5.856248     7.055309
# min       259.350000     1.000000     0.100000  1953.000000
# 25%      5500.000000    72.000000     1.600000  2004.000000
# 50%      9001.575000   130.000000     2.000000  2008.000000
# 75%     16300.000000   196.000000     2.500000  2011.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
'''
fig = plt.figure(figsize = (10,6))
sns.catplot(x = 'price', data = Car_data, kind='count')'''
# Out:
# "\nfig = plt.figure(figsize = (10,6))\nsns.catplot(x = 'price', data = Car_data, kind='count')"

# %%
# Taking out the extreem values(outliers)
min_out_pric, max_out_pric = Car_data.price.quantile([0.05, 0.95])
min_out_pric, max_out_pric
# Out:
# (2000.0, 47000.0)

# %%
# Remove the outliers
Car_data2 = Car_data[(Car_data.price<max_out_pric) & (Car_data.price>min_out_pric)]

# %%
# Check the statistics of the data 
Car_data2.describe()
# Out:
#               price      mileage         engV         year
# count   8399.000000  8399.000000  8399.000000  8399.000000
# mean   11952.367708   145.936659     2.522106  2006.865817
# std     8836.955883    94.322390     5.534129     6.052342
# min     2020.000000     1.000000     0.110000  1953.000000
# 25%     5900.000000    81.000000     1.600000  2004.000000
# 50%     9100.000000   135.000000     2.000000  2008.000000
# 75%    15000.000000   198.000000     2.500000  2011.000000
# max    46999.000000   999.000000    99.990000  2016.000000

# %%
# Taking out the extreem values(outliers)
min_out_mil, max_out_mil = Car_data2.mileage.quantile([0.05, 0.95])
min_out_mil, max_out_mil
# Out:
# (5.0, 310.0)

# %%
# Remove the outliers
Car_data2 = Car_data2[(Car_data2.mileage<max_out_mil) & (Car_data2.mileage>min_out_mil)]

# %%
# Check the statistics of the data 
Car_data2.describe()
# Out:
#               price      mileage         engV         year
# count   7541.000000  7541.000000  7541.000000  7541.000000
# mean   11932.234875   140.903726     2.501420  2007.158202
# std     8587.644675    70.876743     5.323887     5.220830
# min     2020.000000     6.000000     0.110000  1961.000000
# 25%     6100.000000    87.000000     1.600000  2005.000000
# 50%     9300.000000   135.000000     2.000000  2008.000000
# 75%    14900.000000   190.000000     2.500000  2011.000000
# max    46999.000000   309.000000    99.990000  2016.000000

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
# Insert your code here...
profile = Car_data2.profile_report(title="Car Data Profiling after Data processing", progress_bar=False, minimal=True)
profile.to_file(output_file="Car_data_profiling_b_after_processing.html")

# %%
profile
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-06-10 15:24:08.646749&quot;&gt;&lt;title&gt;Car Data Profiling after Data processing&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %%
# Insert your code here...
plt.figure(figsize=(12,6))
sns.heatmap(Car_data2.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# fig = plt.figure(figsize = (30,10))
# sns.barplot(x = 'car', y='price' ,data = Car_data2)
# plt.xticks(rotation=90)
# plt.show()

# %%
fig = plt.figure(figsize = (30,10))
sns.barplot(x = 'car', y='mileage' ,data = Car_data2)
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (60,20))
sns.barplot(x = 'mileage', y='price' ,data = Car_data2)
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize = (30,10))
sns.barplot(x = 'year', y='mileage' ,data = Car_data2)
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize = (30,10))
sns.barplot(x = 'year', y='price' ,data = Car_data2)
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize = (30,10))
sns.barplot(x = 'year', y='engV' ,data = Car_data2)
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize = (30,10))
sns.barplot(x = 'engV', y='mileage' ,data = Car_data2)
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'registration', y='price' ,data = Car_data2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# - In this part you need to provide a conclusion about your overall analysis.
#
# - Write down some short points that you have observed so far.

# %% [markdown]
# 1. Car is avialable for reselling with registration and withought registration
# 2. The car with registration is costly.
# 3. The less variation in Car engine can be observed except 1989 where company comes with 8 version of engine
# 4. In 1969 the price of Car was highest and overall, after 1969 year the price droped and incereased every year since then.
# 5. The mileage of the car is decreasing as the year passess.
# 6. The car price has increased but the milease is decreasing.
# 7. As the mileage increase the price is droping
# 8. Lancia car have maximum mileage and Rolls-Royce have minimum mileage
# 9. The year wise car price is increasing
# 10. Enging version is improved with passing years
# 11. Engine Version 5.4 has highest mileage

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# - This is a very crucial part where you will present your actionable insights.
# - You need to give suggestions about what could be applied and what not.
# - Make sure that these suggestions are short and to the point, ultimately it's a catalyst to your business.

# %% [markdown]
# 1. Company should work on mileage improvement of the car as the mileage is decreasing by years
# 2. The company should try to sell the car first which has highest mileage as it is cheaper compare in price.
# 3. The car with registration having high price, the price can be moderated to sell the car.
# 4. Make the registration and warranty of non-registered car with moderate price to build customer trust.
